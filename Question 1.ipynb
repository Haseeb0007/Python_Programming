# %%
person = {'first_name': 'Abdul','last_name': 'Haseeb','age': 20,'city': 'Karachi',}

print(person['first_name'])
print(person['last_name'])
print(person['age'])
print(person['city'])


person['Qualification']='inter'

print(person['Qualification'])
# Out:
# Abdul
# Haseeb
# 20
# Karachi
# inter
