# %%
F_name=input("Enter First Name")

L_name=input("Enter Last Name")

Reverse_Fname=reversed(F_name)

Reverse_Lname=reversed(L_name)

Result1=("".join(Reverse_Lname))

Result2=("".join(Reverse_Fname))

print(Result1+" "+Result2)
# Out:
# Enter First NameABDUL
# Enter Last NameHASEEB
# BEESAH LUDBA
