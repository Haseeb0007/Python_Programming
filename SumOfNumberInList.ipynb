# %%
lst = []
num = int(input('How many numbers: '))
for n in range(num):
    numbers = int(input('Enter number '))
    lst.append(numbers)
print("Sum of elements in given list is :", sum(lst))
# Out:
# How many numbers: 2
# Enter number 12
# Enter number 13
# Sum of elements in given list is : 25
